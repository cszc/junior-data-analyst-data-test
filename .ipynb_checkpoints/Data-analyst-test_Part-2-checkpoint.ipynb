# %% [markdown]
# # 2) Applied Question
# ## Modeling High or Low Gas Mileage
#
# For this second applied question you will develop several predictive models. These should be written in R or Python and the code should be submitted. The models will predict whether a car will get high or low gas mileage. The question will be based on the Cars_mileage data set that is a part of this repo.
#
# March 19, 2017

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import seaborn as sns
import numpy as np
import csv
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
#Importing specific scikitlearn modules
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import ParameterGrid, StratifiedKFold
from sklearn.metrics import *

# %% [markdown]
# ## Supplemental Analysis
#
# In the following sections, I walk through some preliminary analysis required to answer the provided questions.
# - Supplemental 1: Preliminary Data Exploration
#     - Includes descriptive statistics, visualization of distributions, and checking for null values.
# - Supplemental 2: Cleaning and Imputation
#     - I create separate columns for the make and models and impute missing values in the ***horsepower*** column.
# - Supplemental 3: General Description of Data & Assumptions
#     - After I perform the initial exploration and cleaning, I provide a high level overview of the data and my assumptions.

# %% [markdown]
# ### Supplemental 1: Preliminary Data Exploration

# %%
# Read in CSV. Get row count and number of unique makes & models. Examine first few rows.

df = pd.read_csv("Cars_mileage.csv")
unique_cars = sorted(list(df.name.unique()))
print("The total number of rows in this dataset: {}".format(len(df)))
print("The number of unique car make & models: {}".format(len(unique_cars)))
df.head()
# Out:
# The total number of rows in this dataset: 397
# The number of unique car make & models: 304
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Top 10 most popular cars
df['name'].value_counts().head(10)
# Out:
# ford pinto            6
# amc matador           5
# ford maverick         5
# toyota corolla        5
# chevrolet chevette    4
# amc hornet            4
# toyota corona         4
# chevrolet impala      4
# amc gremlin           4
# peugeot 504           4
# Name: name, dtype: int64

# %%
# Top 10 most efficient cars. Note the '?' in the horsepower column.
df.sort_values('mpg', ascending=False).head(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 322  46.6          4          86.0         65    2110          17.9    80
# 329  44.6          4          91.0         67    1850          13.8    80
# 325  44.3          4          90.0         48    2085          21.7    80
# 393  44.0          4          97.0         52    2130          24.6    82
# 326  43.4          4          90.0         48    2335          23.7    80
# 244  43.1          4          90.0         48    1985          21.5    78
# 309  41.5          4          98.0         76    2144          14.7    80
# 330  40.9          4          85.0          ?    1835          17.3    80
# 324  40.8          4          85.0         65    2110          19.2    80
# 247  39.4          4          85.0         70    2070          18.6    78
#
#      origin                             name
# 322       3                        mazda glc
# 329       3              honda civic 1500 gl
# 325       2             vw rabbit c (diesel)
# 393       2                        vw pickup
# 326       2               vw dasher (diesel)
# 244       2  volkswagen rabbit custom diesel
# 309       2                        vw rabbit
# 330       2             renault lecar deluxe
# 324       3                       datsun 210
# 247       3                   datsun b210 gx

# %%
# Get descriptive statistics for dataframe
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# Since we are interested in mpg specifically, let's look at its distribution.
ax = df['mpg'].hist(bins=30)
ax.set_title('Distribution of MPG')

# %%
# Get unique values for categorical variables
print("Unique Values for Categorical Variables\n")
print('origins: ' + str(sorted(df['origin'].unique())))
print('years: ' + str(sorted(df['year'].unique())))
print('cylinders: ' + str(sorted(df['cylinders'].unique())))
# Out:
# Unique Values for Categorical Variables
#
# origins: [1, 2, 3]
# years: [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82]
# cylinders: [3, 4, 5, 6, 8]

# %%
## Doing a preliminary check for nulls
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# ### Supplemental 2: Data Cleaning & Imputation
#
# In this section I create a cleaned dataframe (*clean_df*) to be used for modeling. To do so, I clean up a few issues with the data.
#
# First, horsepower has a few missing values denoted in the dataset with *'?'*. Because of the use of this character, Pandas has interpeted the data type of this column as "object" types. I will convert this column to a numerical value and then impute the missing values with the median horsepower.
#
# Secondly, car makes don't look to be standardized. In this section, I'll manually create a dictionary of definitive make names, and replace the erroneous makes with the standard ones. Then I add three new columns to *clean_df* for the make, basic model, and full model.

# %%
# First, I convert any object types to numerical values. Then I check for nulls.
clean_df = df.copy().convert_objects(convert_numeric=True)
clean_df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# #### Imputation
# It appears that ***horsepower*** is missing 5 values. Here, I'll impute it with the median.
# Other common optionos are '0' or the mean. In this case, 0 doesn't seem to be a useful value for imputation since it's impossible for a car to have 0 horsepower. Additionally, the distribution shows that horsepower is somewhat normally distributed, but has a long tail, pulling the mean to the right. Therefore, we'll use the median as the imputation value to be safe.

# %%
clean_df['horsepower'].hist(bins=30)
print(clean_df['horsepower'].describe())
hp_median = clean_df['horsepower'].median()
clean_df['horsepower']=clean_df['horsepower'].fillna(value=hp_median)
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %% [markdown]
# #### Extracting Makes and Models
# Here, I manually create a dictionary of erroneous ***make*** names to ones I've standardized through inspection and my own general knowledge.
# Then, I use Pandas' apply function to create a new column for the ***make***,
# ***basic_model***, and ***full_model***. I try to capture the essential model information in
# ***basic_model***, e.g. whether or not it is a Camry or a Rabbit. The column ***full_model*** will capture all of the model information, including model class and trim level.

# %%
to_remove = {'vw': 'volkswagen', 
             'vokswagen':'volkswagen', 
             'maxda':'mazda', 
             'mercedes':'mercedes-benz', 
             'chevy':'chevrolet', 
             'chevroelt':'chevrolet', 
             'toyouta':'toyota'}

def cleanMake(x):
    '''
    Takes a string and returns the first element of the string separated by spaces.
    '''
    make = x.split(' ')[0]
    if make in to_remove.keys():
        return to_remove[make]
    return make

def cleanModel(x, basic=True):
    '''    
    Takes a string.
    If basic is true, returns the second element of the string separated by spaces.
    Otherwise, it returns everything after the first element of the string.
    '''
    try:
        if basic:
            return x.split(' ')[1]
        else:
            return ' '.join(x.split(' ')[1:])
    except:
        return ''

clean_df['make'] = clean_df['name'].apply(cleanMake)
clean_df['basic_model'] = clean_df['name'].apply(cleanModel)
clean_df['full_model'] = clean_df['name'].apply(cleanModel, args=(False,))

print('Unique Makes: {}'.format(len(list(clean_df['make'].unique()))))
print(list(clean_df['make'].unique()))
print()
print('Unique Basic Models: {}'.format(len(list(clean_df['basic_model'].unique()))))
print(list(clean_df['basic_model'].unique()))
print()
print('Unique Full Models: {}'.format(len(list(clean_df['full_model'].unique()))))
print(list(clean_df['full_model'].unique()))
print()
clean_df.head()
# Out:
# Unique Makes: 30
# ['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac', 'dodge', 'toyota', 'datsun', 'volkswagen', 'peugeot', 'audi', 'saab', 'bmw', 'hi', 'mercury', 'opel', 'fiat', 'oldsmobile', 'chrysler', 'mazda', 'volvo', 'renault', 'honda', 'subaru', 'capri', 'mercedes-benz', 'cadillac', 'triumph', 'nissan']
#
# Unique Basic Models: 190
# ['chevelle', 'skylark', 'satellite', 'rebel', 'torino', 'galaxie', 'impala', 'fury', 'catalina', 'ambassador', 'challenger', "'cuda", 'monte', 'estate', 'corona', 'duster', 'hornet', 'maverick', 'pl510', '1131', '504', '100', '99e', '2002', 'gremlin', 'f250', 'c20', 'd200', '1200d', 'vega', 'pinto', 'matador', 'monaco', 'country', 'safari', 'firebird', 'mustang', 'capri', '1900', '304', '124b', 'corolla', '1200', 'model', 'cricket', 'colt', 'type', 'marquis', 'lesabre', 'delta', 'newport', 'rx2', 'gran', '145e', '411', '12', '510', 'century', 'malibu', 'coronet', 'caprice', 'ltd', 'new', 'electra', 'valiant', 'nova', 'super', 'custom', 'vista', 'carina', '610', 'rx3', '124', 'grand', '128', 'manta', '100ls', '144ea', 'dart', '99le', 'mark', 'omega', 'b210', 'fox', 'dasher', '710', 'civic', '', 'x1.9', 'monarch', 'bel', 'skyhawk', 'monza', 'astro', 'rabbit', 'pacer', '244dl', '131', 'ii', '12tl', 'chevette', 'woody', 'aspen', 'granada', 'ventura', 'b-210', '245', 'volare', '280s', 'seville', 'c10', 'f108', 'd100', 'accord', 'opel', '5', 'arrow', 'f-10', 'cutlass', 'cougar', 'concours', 'cordoba', 'thunderbird', 'sunbird', 'dl', '810', '320i', 'rx-4', 'fiesta', 'glc', 'diplomat', 'phoenix', 'fairmont', 'concord', 'zephyr', 'regal', 'futura', 'magnum', 'omni', 'celica', 'sapporo', 'starfire', '200-sx', '5000', '264gl', '99gle', '604sl', 'scirocco', 'lemans', 'st.', 'lebaron', 'spirit', 'benz', 'eldorado', 'horizon', '210', 'strada', 'citation', '310', '4000', '626', '5000s', '240d', 'lecar', '280-zx', 'rx-7', 'tr7', 'reliant', 'aries', 'starlet', 'champ', 'tercel', 'escort', 'jetta', '18i', 'prelude', '200sx', '505s', 'diesel', 'cressida', 'cavalier', 'j2000', 'lynx', 'stanza', 'charger', 'camaro', 'pickup', 'rampage', 'ranger', 's-10']
#
# Unique Full Models: 299
# ['chevelle malibu', 'skylark 320', 'satellite', 'rebel sst', 'torino', 'galaxie 500', 'impala', 'fury iii', 'catalina', 'ambassador dpl', 'challenger se', "'cuda 340", 'monte carlo', 'estate wagon (sw)', 'corona mark ii', 'duster', 'hornet', 'maverick', 'pl510', '1131 deluxe sedan', '504', '100 ls', '99e', '2002', 'gremlin', 'f250', 'c20', 'd200', '1200d', 'vega 2300', 'corona', 'pinto', 'satellite custom', 'torino 500', 'matador', 'catalina brougham', 'monaco (sw)', 'country squire (sw)', 'safari (sw)', 'hornet sportabout (sw)', 'vega (sw)', 'firebird', 'mustang', 'capri 2000', '1900', '304', '124b', 'corolla 1200', '1200', 'model 111', 'cricket', 'corona hardtop', 'colt hardtop', 'type 3', 'vega', 'pinto runabout', 'ambassador sst', 'marquis', 'lesabre custom', 'delta 88 royale', 'newport royal', 'rx2 coupe', 'matador (sw)', 'chevelle concours (sw)', 'gran torino (sw)', 'satellite custom (sw)', '145e (sw)', '411 (sw)', '504 (sw)', '12 (sw)', 'pinto (sw)', '510 (sw)', 'corona mark ii (sw)', 'colt (sw)', 'corolla 1600 (sw)', 'century 350', 'malibu', 'gran torino', 'coronet custom', 'marquis brougham', 'caprice classic', 'ltd', 'fury gran sedan', 'new yorker brougham', 'electra 225 custom', 'ambassador brougham', 'valiant', 'nova custom', 'super beetle', 'country', 'custom suburb', 'vista cruiser', 'carina', '610', 'rx3', 'capri v6', '124 sport coupe', 'monte carlo s', 'grand prix', '128', 'manta', '100ls', '144ea', 'dart custom', '99le', 'mark ii', 'omega', 'nova', 'b210', 'chevelle malibu classic', 'satellite sebring', 'century luxus (sw)', 'coronet custom (sw)', 'fox', 'dasher', '710', 'colt', '124 tc', 'civic', '', 'x1.9', 'valiant custom', 'monarch', 'bel air', 'grand fury', 'century', 'fury', 'skyhawk', 'monza 2+2', 'mustang ii', 'corolla', 'astro', 'rabbit', 'pacer', '244dl', 'civic cvcc', '131', 'ii', '12tl', 'coronet brougham', 'chevette', 'woody', 'aspen se', 'granada ghia', 'ventura sj', 'pacer d/l', 'b-210', '245', 'volare premier v8', '280s', 'seville', 'c10', 'f108', 'd100', 'accord cvcc', 'opel isuzu deluxe', '5 gtl', 'arrow gs', 'f-10 hatchback', 'cutlass supreme', 'monaco brougham', 'cougar brougham', 'concours', 'skylark', 'volare custom', 'granada', 'grand prix lj', 'monte carlo landau', 'cordoba', 'thunderbird', 'rabbit custom', 'sunbird coupe', 'corolla liftback', 'mustang ii 2+2', 'colt m/m', 'dl', '810', '320i', 'rx-4', 'rabbit custom diesel', 'fiesta', 'glc deluxe', 'b210 gx', 'cutlass salon brougham', 'diplomat', 'monarch ghia', 'phoenix lj', 'fairmont (auto)', 'fairmont (man)', 'volare', 'concord', 'century special', 'zephyr', 'aspen', 'concord d/l', 'regal sport coupe (turbo)', 'futura', 'magnum xe', '510', 'omni', 'celica gt liftback', 'sapporo', 'starfire sx', '200-sx', '5000', '264gl', '99gle', '604sl', 'scirocco', 'accord lx', 'lemans v6', 'zephyr 6', 'fairmont 4', 'concord dl 6', 'aspen 6', 'ltd landau', 'grand marquis', 'st. regis', 'malibu classic (sw)', 'lebaron town @ country (sw)', 'colt hatchback custom', 'spirit dl', 'benz 300d', 'eldorado', 'horizon', 'horizon tc3', '210', 'strada custom', 'skylark limited', 'citation', 'omega brougham', 'phoenix', 'corolla tercel', '310', 'fairmont', '4000', 'corona liftback', '626', '510 hatchback', 'glc', 'rabbit c (diesel)', 'dasher (diesel)', '5000s (diesel)', '240d', 'civic 1500 gl', 'lecar deluxe', '280-zx', 'rx-7 gs', 'tr7 coupe', 'mustang cobra', 'accord', 'reliant', 'aries wagon (sw)', 'starlet', 'champ', 'civic 1300', '210 mpg', 'tercel', 'glc 4', 'horizon 4', 'escort 4w', 'escort 2h', 'jetta', '18i', 'prelude', '200sx', '505s turbo diesel', 'diesel', 'cressida', '810 maxima', 'cutlass ls', 'granada gl', 'lebaron salon', 'cavalier', 'cavalier wagon', 'cavalier 2-door', 'j2000 se hatchback', 'aries se', 'fairmont futura', 'rabbit l', 'glc custom l', 'glc custom', 'horizon miser', 'lynx l', 'stanza xe', 'civic (auto)', '310 gx', 'century limited', 'cutlass ciera (diesel)', 'lebaron medallion', 'granada l', 'celica gt', 'charger 2.2', 'camaro', 'm ...
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name       make basic_model       full_model
# 0       1  chevrolet chevelle malibu  chevrolet    chevelle  chevelle malibu
# 1       1          buick skylark 320      buick     skylark      skylark 320
# 2       1         plymouth satellite   plymouth   satellite        satellite
# 3       1              amc rebel sst        amc       rebel        rebel sst
# 4       1                ford torino       ford      torino           torino

# %% [markdown]
# ### Supplemental 3: General Description of Data & Assumptions
# There are 397 rows in this dataset, representing 30 unique makes and 299 unique models & classes. There appear to be no null values. Each row is represented by 9 columns:
#
# Column Name | Variable Type | Data Type | Description
# -----|-----|-----|----
# mpg | continuous | float | Miles per Gallon. Min is 9 mpg, max is 46.6 mpg, mean and median are 23.5 and 23 mpg respectively
# cylinders | discrete/categorical | int | Ranges from 3-8 cylinders, with most cars having 4.
# displacement | continuous | float | The total volume of the cylinders. Min is 68, max is 455. Mean and median are 193.5 and 146, respectively. I'm assuming cc units.
# horsepower | continuous | float | The power of the engine. Min is 46, max is 230, mean and median are 104 and 93.5, respectively.
# weight | continuous | int | Cars weigh between 1613-5140, I'm assuming in pounds.
# acceleration | continuous | float | Min is 8, max is 24.8, mean and median are 15.6 and 15.5, respectively.
# year | discrete/categorical | int | The cars were made in the years spanning 1970 - 1982
# origin | discrete/categorical | int | There are three origins - 1, 2, and 3. I'm asuming these are categorical, i.e. the numbers are not ordinal.
# name | discrete/categorical | string | The make and model. There are 304 unique strings for 397 rows.
#
# In addition to these, I've added three new categorical variables as strings: ***make***, ***basic_model***, and ***full_model***.
#
# The 5 most popular vehicles in this dataset are the Ford Pinto, AMC Matador, Toyota Corolla, Ford Maverick, and Chevorlet Impala. A 1980 Mazda GLC is the most efficeint at 46.6 miles per gallon.

# %% [markdown]
# ## Part A
# Create a binary variable that represents whether the car's mpg is above or below its median. Above the median should be represented as 1. Name this variable mpg_binary.

# %%
median = clean_df['mpg'].median()
clean_df['mpg_binary'] = ((df['mpg'] > median) * 1)
ax = clean_df['mpg_binary'].hist(bins=2)
ax.set_title("Distribution of mpg_binary")
clean_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name       make basic_model       full_model  \
# 0       1  chevrolet chevelle malibu  chevrolet    chevelle  chevelle malibu
# 1       1          buick skylark 320      buick     skylark      skylark 320
# 2       1         plymouth satellite   plymouth   satellite        satellite
# 3       1              amc rebel sst        amc       rebel        rebel sst
# 4       1                ford torino       ford      torino           torino
#
#    mpg_binary
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ## Part B
# Which of the other variables seem most likely to be useful in predicting whether a car's mpg is above or below its median? Describe your findings and submit visual representations of the relationship between mpg_binary and other variables.

# %% [markdown]
# ### Correlation
# If we look at the correlation table and matrix for non-categorical variables (see the last row for mpg_binary), ***cylinders***, ***displacement***, and ***weight*** are the most likely candidates to be good predictors given their relateively high negative correlation with ***mpg_binary***.  ***Horsepower*** also has a relatively high negative correlation.

# %%
clean_df.drop(['origin', 'mpg'], axis=1, inplace=False).corr()
# Out:
#               cylinders  displacement  horsepower    weight  acceleration  \
# cylinders      1.000000      0.950920    0.841536  0.897017     -0.504061
# displacement   0.950920      1.000000    0.895765  0.933104     -0.544162
# horsepower     0.841536      0.895765    1.000000  0.862590     -0.688167
# weight         0.897017      0.933104    0.862590  1.000000     -0.419502
# acceleration  -0.504061     -0.544162   -0.688167 -0.419502      1.000000
# year          -0.346717     -0.369804   -0.413992 -0.307900      0.282901
# mpg_binary    -0.740327     -0.738607   -0.646915 -0.745734      0.322629
#
#                   year  mpg_binary
# cylinders    -0.346717   -0.740327
# displacement -0.369804   -0.738607
# horsepower   -0.413992   -0.646915
# weight       -0.307900   -0.745734
# acceleration  0.282901    0.322629
# year          1.000000    0.454108
# mpg_binary    0.454108    1.000000

# %%
corr = clean_df.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=corr.columns.values, yticklabels=corr.columns.values,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

ax.set_title('Correlation Matrix')

# %% [markdown]
# ### Visualizing the Relationships Between mpg_binary and Other Variables

# %%
'''
In this plot, we see that cars with above median gas mileage are overwhelmingly 
more likely to have only 4 cylinders. It also appears that most of the efficient
cars have a displacement below 200.
'''
bx = sns.swarmplot(y= "displacement", x="mpg_binary", hue="cylinders", data=clean_df);
bx.set_title("Relationship Between Efficiency and Displacement/Cylinders")

# %%
'''
This graph explores the relationship between cylinders and displacement a bit more. 
It makes sense that the more cylinders you have, the more volume would be displaced.
Given this, I would expect both variables to be useful predictors. However, they would 
be providing much the same information.
'''
ax = clean_df.plot(kind='scatter', x="displacement", y="cylinders")
ax.set_title("Relationship Between Cylinders and Displacemnet")

# %%
'''
Here, we see that most cars with above median gas mileage are under 3000 pounds.
It also appears that efficient cars are of mixed origin. However, inefficient cars
are more than likely to be of origin 1.
'''
ax = sns.swarmplot(y="weight", x="mpg_binary", hue="origin", data=clean_df)
ax.set_title("Relationship Between Efficiency and Weight")

# %%
'''
Again, in this graph, we see that efficient cars have relatively low horsepower, with most
being below 100. We also see, unsurprisingly, that there is a relatinship between horsepower
and cylinders, with fewer cylinders corresponding to lower horsepower.
'''
ax = sns.swarmplot(y="horsepower", x="mpg_binary", hue="cylinders", data=clean_df)
ax.set_title("Relationship Between Horsepower and Weight")
# JC: This graph doesn't involve weight, as the title suggests.

# %% [markdown]
# ### Conclusion
# ***Horsepower***, ***cylinders***, ***weight***, and ***displacement*** seem to be likely candidates for useful predictors.
#
# However, from the correlation table, we see they are also all highly correlated with one another. Therefore, while these variables might prove useful, they might all be accounting for the same information.
#
# Categorical variables such as ***origin*** could provide additional lift.

# %% [markdown]
# ## Part C
# Split the data into a training set and a test set.

# %% [markdown]
# ### Adding Dummy Variables
# Certain models such as decision trees are unable to take categorical variables. To fix this, we'll add a separate binary column for each category. A row will be assigned a 1 if it falls in that category, and 0 otherwise. (JC: I've also heard these called "one-hot" columns).

# %%
def add_dummies(df, col):
    '''
    Takes a dataframe and a column (string)
    Returns a new dataframe with columns added for each category 
    and the original column removed.
    '''
    # Each new column is prefixed with the first 4 letters of the original column
    dummy_df = pd.get_dummies(df[col], prefix=col[0:4])
    df.drop(col, axis=1, inplace=True)
    return pd.concat([df, dummy_df], axis=1)

# %%
discrete_vars = ['make', 'cylinders', 'origin', 'year', 'name', 'basic_model', "full_model"]

for column in discrete_vars:
    clean_df = add_dummies(clean_df, column)

# %%
# There are 848 features in the final dataframe that will be used for modeling
clean_df.columns
# Out:
# Index(['mpg', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'mpg_binary', 'make_amc', 'make_audi', 'make_bmw', 'make_buick',
#        ...
#        'full_vega 2300', 'full_ventura sj', 'full_vista cruiser',
#        'full_volare', 'full_volare custom', 'full_volare premier v8',
#        'full_woody', 'full_x1.9', 'full_zephyr', 'full_zephyr 6'],
#       dtype='object', length=850)

# %% [markdown]
# ### Splitting into Testing and Training Sets
# The data set is randomly split into a training set and test set, with 1/3 in testing and 2/3 in training. (JC: Why those ratios?)

# %%
'''
Here, I separate the columns into X, the dependent variable (mpg_binary) 
and y, the features (predictors). I remove mpg_binary and mpg from the feature set.
Then I use train_test_split to randomly separate the rows in test and train sets. 
'''
X, y = clean_df.drop(['mpg_binary', 'mpg'], axis=1), clean_df['mpg_binary']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Part D
# Perform two of the following in order to predict mpg_binary:
#
# - LDA (Linear discriminant analysis)
# - QDA (Quadratic discriminant analysis)
# - Logistic regression
# - KNN (K-nearest neighbors)
# - Decision Tree
# - Random Forests
# - Gradient Boosting
# - LASSO (Least Absolute Shrinkage and Selection Operator)
# - Elastic Net Method
# - Ridge regression analysis
#
# For each of the two you select: What is the test error(s) of the model obtained? Do you have any other observations?

# %% [markdown]
# ### Modeling
# stuff

# %%
# clfs = {
#         'LR': LogisticRegression(penalty = 'l1', C = 1e5),
#         'DT': DecisionTreeClassifier()
#         }

# model_grid = {
#         'DT': {'criterion': ['gini', 'entropy'], 
#                'max_depth': [1, 2, 15,20,30,40,50], 
#                'max_features': ['sqrt','log2'],
#                'min_samples_split': [2,5,10], 
#                'random_state': [1]},
#         'LR': {'penalty': ['l1','l2'], 
#                'C': [0.00001,0.0001,0.001,0.01,0.1,1,10], 
#                'random_state': [1]}
#          }

#classifiers to run through
clfs = {'RF': RandomForestClassifier(n_estimators = 50, n_jobs = -1),
        'LR': LogisticRegression(penalty = 'l1', C = 1e5),
        'GB': GradientBoostingClassifier(learning_rate = 0.05, subsample = 0.5, max_depth = 6, n_estimators = 10),
        'DT': DecisionTreeClassifier()
        }

#params to run through for each classifier
model_grid = {
        'DT': {'criterion': ['gini', 'entropy'], 
               'max_depth': [1, 2, 15,20,30,40,50], 
               'max_features': ['sqrt','log2'],
               'min_samples_split': [2,5,10], 
               'random_state': [1]},
        'LR': {'penalty': ['l1','l2'], 
               'C': [0.00001,0.0001,0.001,0.01,0.1,1,10], 
               'random_state': [1]},
        'RF': {'n_estimators': [1,10,100,1000], 
              'max_depth': [10,15,20,30,40,50], 
              'max_features': ['sqrt','log2'],
              'min_samples_split': [2,5,10], 
              'random_state': [1]},
        'GB': {'n_estimators': [1,10,100,1000], 
               'learning_rate' : [0.001,0.01,0.05,0.1,0.5],
               'subsample' : [0.1,0.5,1.0], 
               'max_depth': [1,3,5,10,20,50,100],
               'random_state': [1]}
         }

# %%
from collections import defaultdict

class Model():
    def __init__(self, clf, model_id, model_type, params, n_splits, X, y):
        self.model_id = model_id
        self.model_type = model_type
        self.params = params
        self.n_splits = n_splits
        self.X = X
        self.y = y
        self.skf = StratifiedKFold(n_splits=n_splits)
        self.results_by_split = {}
        self.results_by_metric = defaultdict(self._dict_list)
        self.feature_importances_by_split = {}
        self.clf = clf.set_params(**self.params)
        self.metrics = ['roc_auc', 'precision', 'recall', 'accuracy']
    
    def cross_validate(self):
        '''
        '''
        for i, (train_index, test_index) in enumerate(self.skf.split(self.X, self.y)):
            X_train, X_test = X.loc[train_index], X.loc[test_index]
            y_train, y_test = y[train_index], y[test_index]
            fit = self.clf.fit(X_train, y_train)
            scores = self._score_model(fit, X_test, y_test)
            fit = self.clf.fit(X_train, y_train)
            self.results_by_split[i + 1] = scores
            importances = self.clf.feature_importances_
            self.feauture_importances_by_split[i + 1] = (
                sorted(list(zip(importances, list(y_train.columns))), reverse=True)[:10])
            
        self._set_results_by_metric()
    
    def get_feature_importance(self):
        if self.model_type == 'LR':
        else:
            importances = self.clf.feature_importances_
            self.feauture_importances_by_split[i + 1] = (
                sorted(list(zip(importances, list(y_train.columns))), reverse=True)[:10])
            
    def get_avg_results(self):
        '''
        '''
        results = {}
        for threshold, metrics in self.results_by_metric.items():
            avg_scores = {}
            for metric, scores in metrics.items():
                avg_scores['{}_avg'.format(metric)] = np.mean(scores)
                avg_scores['{}_std'.format(metric)] = np.std(scores)
            results[threshold] = avg_scores
        return results
                
    def _dict_list(self):
        return defaultdict(list)
    
    def get_sorted_rows(self, kind='eval'):
        '''
        '''
        try:
            if kind == 'eval':
                results = self.get_avg_results()
                rows = []
                for threshold in sorted(results.keys()):
                    row = self.get_model_info_dict()
                    row.update(results[threshold])
                    row.update(self.params)
                    row['threshold'] = threshold
                    rows.append(row)
                return rows
            elif kind == 'splits':
                pass
            elif kind == 'feautures':
                pass
        except:
            print("Sorry, I don't understand that kind. Please use 'eval', 'splits', or 'features'.")
            
    def get_eval_rows(self):
        results = self.get_avg_results()
        rows = []
        for threshold in sorted(results.keys()):
            row = self.get_model_info_dict()
            row.update(results[threshold])
            row.update(self.params)
            row['threshold'] = threshold
            rows.append(row)
        return rows
    
    def get_split_rows(self):
        rows = []
        for split, results in self.results_by_split.items():
            for threshold in sorted(results.keys()):
                row = self.get_model_info_dict()
                row.update(results[threshold])
                row['threshold'] = threshold
                row['split'] = split
                rows.append(row)
        return rows
    
    def get_model_info_dict(self):
        return {'model_id': self.model_id,
                'model_type': self.model_type,
                'params': str(self.params)}
    
    def _set_results_by_metric(self):
        for thresholds in self.results_by_split.values():
            for threshold, metrics in thresholds.items():
                for metric, result in metrics.items():
                    self.results_by_metric[threshold][metric].append(result)
                    
    def _score_model(self, fit, X_test, y_test):
        '''
        '''
        y_pred = fit.predict(X_test)
        y_prob = fit.predict_proba(X_test)[:,1]
        scores = self._get_scores_for_range(y_test, y_prob)
        return scores

    def _get_scores_for_range(self, y_test, y_prob, lower=.5, upper=1, step=.1, precision = True, recall=True, accuracy=True):
        '''
        returns dictionary of scores at thresholds
        '''
        scores = {}
        roc_auc = roc_auc_score(y_test, y_prob)
        for threshold in np.arange(lower, upper, step):
            precision, recall, accuracy = self._get_scores_at_threshold(y_test, y_prob, threshold)
            scores[str(threshold)] = {'roc_auc': roc_auc, 'precision': precision, 'recall': recall, 'accuracy': accuracy}
        return scores

    def _get_scores_at_threshold(self, y_true, y_prob, threshold):
        '''
        Dynamic threshold for scores.
        '''
        y_pred = np.asarray([1 if i >= threshold else 0 for i in y_prob])
        return precision_score(y_true, y_pred), recall_score(y_true, y_pred), accuracy_score(y_true, y_pred)

# %%
X, y = clean_df.drop(['mpg_binary', 'mpg'], axis=1), clean_df['mpg_binary']

def run_param_loop(model, loop_count, X, y, clf, n_splits):
    '''
    '''
    model_id = "{}_paramset-{}".format(model, loop_count)
    model = Model(clf, model_id, model, params, n_splits, X, y)
    model.cross_validate()
    eval_rows = model.get_eval_rows()
    #feat_rows = model.get_sorted_rows(kind='features')
    split_rows = model.get_split_rows()
    return eval_rows, split_rows

for model in clfs:
    print('Started running ().'.format(model))
    with open('{}/models.csv'.format(model), 'w') as f, open('{}/splits.csv'.format(model), 'w') as g:
        eval_fieldnames = (['model_id', 'model_type', 'params', 'threshold'] + 
                           list(model_grid[model].keys()) +
                           ['roc_auc_avg', 'roc_auc_std', 'accuracy_avg', 'accuracy_std',
                           'precision_avg', 'precision_std', 'recall_avg', 'recall_std'])

        split_fieldnames = ['model_id', 'model_type', 'params', 'split', 'threshold',
                            'roc_auc', 'accuracy', 'precision', 'recall']

        evalWriter = csv.DictWriter(f, fieldnames=eval_fieldnames)
        splitWriter = csv.DictWriter(g, fieldnames=split_fieldnames)

        evalWriter.writeheader()
        splitWriter.writeheader()
        grid = ParameterGrid(model_grid[model])
        try:
            for i, params in enumerate(grid):
                evals, splits = run_param_loop(model, i+1, X, y, clfs[model], 3)
                evalWriter.writerows(evals)
                splitWriter.writerows(splits)
        finally:
            print('Finished Running Model Type {}. Number of Models Run: {}'.format(model, i))
# Out:
# Finished Running Model Type DT. Number of Models Run: 83
# Finished Running Model Type LR. Number of Models Run: 13
# Finished Running Model Type GB. Number of Models Run: 42
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-a7a565d73a0f> in <module>()
#      30         try:
#      31             for i, params in enumerate(grid):
# ---> 32                 evals, splits = run_param_loop(model, i+1, X, y, clfs[model], 3)
#      33                 evalWriter.writerows(evals)
#      34                 splitWriter.writerows(splits)
#
# <ipython-input-36-a7a565d73a0f> in run_param_loop(model, loop_count, X, y, clf, n_splits)
#       6     model_id = "{}_paramset-{}".format(model, loop_count)
#       7     model = Model(clf, model_id, model, params, n_splits, X, y)
# ----> 8     model.cross_validate()
#       9     eval_rows = model.get_eval_rows()
#      10     #feat_rows = model.get_sorted_rows(kind='features')
#
# <ipython-input-32-35a8fc5db1ab> in cross_validate(self)
#      23             fit = self.clf.fit(X_train, y_train)
#      24             scores = self._score_model(fit, X_test, y_test)
# ---> 25             fit = self.clf.fit(X_train, y_train)
#      26             self.results_by_split[i] = scores
#      27
#
# /home/christine/anaconda3/envs/azavea/lib/python3.5/site-packages/sklearn/ensemble/gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1026         # fit the boosting stages
#    1027         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1028                                     begin_at_stage, monitor, X_idx_sorted)
#    1029         # change shape of arrays after fit (early-stopping or additional ests)
#    1030         if n_stages != self.estimators_.shape[0]:
#
# /home/christine/anaconda3/envs/azavea/lib/python3.5/site-packages/sklearn/ensemble/gradient_boosting.py in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1081             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1082                                      sample_mask, random_state, X_idx_sorted,
# -> 1083                                      X_csc, X_csr)
#    1084
#    1085             # track deviance (= loss)
#
# /home/christine/anaconda3/envs/azavea/lib/python3.5/site-packages/sklearn/ensemble/gradient_boosting.py in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     785             else:
#     786                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 787                          check_input=False, X_idx_sorted=X_idx_sorted)
#     788
#     789             # update tree leaves
#
# /home/christine/anaconda3/envs/azavea/lib/python3.5/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1027             sample_weight=sample_weight,
#    1028             check_input=check_input,
# -> 1029             X_idx_sorted=X_idx_sorted)
#    1030         return self
#    1031
#
# /home/christine/anaconda3/envs/azavea/lib/python3.5/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                            self.min_impurity_split)
#     349
# --> 350         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     351
#     352         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
metrics.precision_recall_fscore_support(X_test, y_pred)
# Out:
# (array([ 0.8852459 ,  0.87323944]),
#  array([ 0.85714286,  0.89855072]),
#  array([ 0.87096774,  0.88571429]),
#  array([63, 69]))

# %% [markdown]
# ### Model 2: Logistic Regression

# %%
importances = clf.feature_importances_
importance2 = sorted(list(zip(importances, list(y_train.columns))), reverse=True)

# %%
importance2
# Out:
# [(0.68299437442471767, 'cyli_4'),
#  (0.058766175771241137, 'weight'),
#  (0.036949004455156677, 'make_volvo'),
#  (0.034467074535434614, 'year_81'),
#  (0.028910510725037371, 'displacement'),
#  (0.024958350600534675, 'acceleration'),
#  (0.019867724340283173, 'year_72'),
#  (0.018227673965378884, 'horsepower'),
#  (0.014989863458370792, 'basi_type'),
#  (0.014529305334722303, 'year_75'),
#  (0.014240370285452253, 'basi_320i'),
#  (0.012565032604810808, 'make_mercury'),
#  (0.011168917870942948, 'basi_celica'),
#  (0.010126485536321601, 'cyli_8'),
#  (0.009764825338595828, 'year_73'),
#  (0.0074743107529992277, 'basi_maverick'),
#  (0.0, 'year_82'),
#  (0.0, 'year_80'),
#  (0.0, 'year_79'),
#  (0.0, 'year_78'),
#  (0.0, 'year_77'),
#  (0.0, 'year_76'),
#  (0.0, 'year_74'),
#  (0.0, 'year_71'),
#  (0.0, 'year_70'),
#  (0.0, 'orig_3'),
#  (0.0, 'orig_2'),
#  (0.0, 'orig_1'),
#  (0.0, 'name_vw rabbit custom'),
#  (0.0, 'name_vw rabbit c (diesel)'),
#  (0.0, 'name_vw rabbit'),
#  (0.0, 'name_vw pickup'),
#  (0.0, 'name_vw dasher (diesel)'),
#  (0.0, 'name_volvo diesel'),
#  (0.0, 'name_volvo 264gl'),
#  (0.0, 'name_volvo 245'),
#  (0.0, 'name_volvo 244dl'),
#  (0.0, 'name_volvo 145e (sw)'),
#  (0.0, 'name_volvo 144ea'),
#  (0.0, 'name_volkswagen type 3'),
#  (0.0, 'name_volkswagen super beetle'),
#  (0.0, 'name_volkswagen scirocco'),
#  (0.0, 'name_volkswagen rabbit l'),
#  (0.0, 'name_volkswagen rabbit custom diesel'),
#  (0.0, 'name_volkswagen rabbit custom'),
#  (0.0, 'name_volkswagen rabbit'),
#  (0.0, 'name_volkswagen model 111'),
#  (0.0, 'name_volkswagen jetta'),
#  (0.0, 'name_volkswagen dasher'),
#  (0.0, 'name_volkswagen 411 (sw)'),
#  (0.0, 'name_volkswagen 1131 deluxe sedan'),
#  (0.0, 'name_vokswagen rabbit'),
#  (0.0, 'name_triumph tr7 coupe'),
#  (0.0, 'name_toyouta corona mark ii (sw)'),
#  (0.0, 'name_toyota tercel'),
#  (0.0, 'name_toyota starlet'),
#  (0.0, 'name_toyota mark ii'),
#  (0.0, 'name_toyota cressida'),
#  (0.0, 'name_toyota corona mark ii'),
#  (0.0, 'name_toyota corona liftback'),
#  (0.0, 'name_toyota corona hardtop'),
#  (0.0, 'name_toyota corona'),
#  (0.0, 'name_toyota corolla tercel'),
#  (0.0, 'name_toyota corolla liftback'),
#  (0.0, 'name_toyota corolla 1600 (sw)'),
#  (0.0, 'name_toyota corolla 1200'),
#  (0.0, 'name_toyota corolla'),
#  (0.0, 'name_toyota celica gt liftback'),
#  (0.0, 'name_toyota celica gt'),
#  (0.0, 'name_toyota carina'),
#  (0.0, 'name_subaru dl'),
#  (0.0, 'name_subaru'),
#  (0.0, 'name_saab 99le'),
#  (0.0, 'name_saab 99gle'),
#  (0.0, 'name_saab 99e'),
#  (0.0, 'name_renault lecar deluxe'),
#  (0.0, 'name_renault 5 gtl'),
#  (0.0, 'name_renault 18i'),
#  (0.0, 'name_renault 12tl'),
#  (0.0, 'name_renault 12 (sw)'),
#  (0.0, 'name_pontiac ventura sj'),
#  (0.0, 'name_pontiac sunbird coupe'),
#  (0.0, 'name_pontiac safari (sw)'),
#  (0.0, 'name_pontiac phoenix lj'),
#  (0.0, 'name_pontiac phoenix'),
#  (0.0, 'name_pontiac lemans v6'),
#  (0.0, 'name_pontiac j2000 se hatchback'),
#  (0.0, 'name_pontiac grand prix lj'),
#  (0.0, 'name_pontiac grand prix'),
#  (0.0, 'name_pontiac firebird'),
#  (0.0, 'name_pontiac catalina brougham'),
#  (0.0, 'name_pontiac catalina'),
#  (0.0, 'name_pontiac astro'),
#  (0.0, 'name_plymouth volare premier v8'),
#  (0.0, 'name_plymouth volare custom'),
#  (0.0, 'name_plymouth volare'),
#  (0.0, 'name_plymouth valiant custom'),
#  (0.0, 'name_plymouth valiant'),
#  (0.0, 'name_plymouth satellite sebring'),
#  (0.0, 'name_plymouth satellite custom (sw)'),
#  (0.0, 'name_plymouth satellite custom'),
#  (0.0, 'name_plymouth satellite'),
#  (0.0, 'name_plymouth sapporo'),
#  (0.0, 'name_plymouth reliant'),
#  (0.0, 'name_plymouth horizon tc3'),
#  (0.0, 'name_plymouth horizon miser'),
#  (0.0, 'name_plymouth horizon 4'),
#  (0.0, 'name_plymouth horizon'),
#  (0.0, 'name_plymouth grand fury'),
#  (0.0, 'name_plymouth fury iii'),
#  (0.0, 'name_plymouth fury gran sedan'),
#  (0.0, 'name_plymouth fury'),
#  (0.0, 'name_plymouth duster'),
#  (0.0, 'name_plymouth custom suburb'),
#  (0.0, 'name_plymouth cricket'),
#  (0.0, 'name_plymouth champ'),
#  (0.0, 'name_plymouth arrow gs'),
#  (0.0, "name_plymouth 'cuda 340"),
#  (0.0, 'name_peugeot 604sl'),
#  (0.0, 'name_peugeot 505s turbo diesel'),
#  (0.0, 'name_peugeot 504 (sw)'),
#  (0.0, 'name_peugeot 504'),
#  (0.0, 'name_peugeot 304'),
#  (0.0, 'name_opel manta'),
#  (0.0, 'name_opel 1900'),
#  (0.0, 'name_oldsmobile vista cruiser'),
#  (0.0, 'name_oldsmobile starfire sx'),
#  (0.0, 'name_oldsmobile omega brougham'),
#  (0.0, 'name_oldsmobile omega'),
#  (0.0, 'name_oldsmobile delta 88 royale'),
#  (0.0, 'name_oldsmobile cutlass supreme'),
#  (0.0, 'name_oldsmobile cutlass salon brougham'),
#  (0.0, 'name_oldsmobile cutlass ls'),
#  (0.0, 'name_oldsmobile cutlass ciera (diesel)'),
#  (0.0, 'name_nissan stanza xe'),
#  (0.0, 'name_mercury zephyr 6'),
#  (0.0, 'name_mercury zephyr'),
#  (0.0, 'name_mercury monarch ghia'),
#  (0.0, 'name_mercury monarch'),
#  (0.0, 'name_mercury marquis brougham'),
#  (0.0, 'name_mercury marquis'),
#  (0.0, 'name_mercury lynx l'),
#  (0.0, 'name_mercury grand marquis'),
#  (0.0, 'name_mercury cougar brougham'),
#  (0.0, 'name_mercury capri v6'),
#  (0.0, 'name_mercury capri 2000'),
#  (0.0, 'name_mercedes-benz 280s'),
#  (0.0, 'name_mercedes-benz 240d'),
#  (0.0, 'name_mercedes benz 300d'),
#  (0.0, 'name_mazda rx2 coupe'),
#  (0.0, 'name_mazda rx-7 gs'),
#  (0.0, 'name_mazda rx-4'),
#  (0.0, 'name_mazda glc deluxe'),
#  (0.0, 'name_mazda glc custom l'),
#  (0.0, 'name_mazda glc custom'),
#  (0.0, 'name_mazda glc 4'),
#  (0.0, 'name_mazda glc'),
#  (0.0, 'name_mazda 626'),
#  (0.0, 'name_maxda rx3'),
#  (0.0, 'name_maxda glc deluxe'),
#  (0.0, 'name_honda prelude'),
#  (0.0, 'name_honda civic cvcc'),
#  (0.0, 'name_honda civic 1500 gl'),
#  (0.0, 'name_honda civic 1300'),
#  (0.0, 'name_honda civic (auto)'),
#  (0.0, 'name_honda civic'),
#  (0.0, 'name_honda accord lx'),
#  (0.0, 'name_honda accord cvcc'),
#  (0.0, 'name_honda accord'),
#  (0.0, 'name_hi 1200d'),
#  (0.0, 'name_ford torino 500'),
#  (0.0, 'name_ford torino'),
#  (0.0, 'name_ford thunderbird'),
#  (0.0, 'name_ford ranger'),
#  (0.0, 'name_ford pinto runabout'),
#  (0.0, 'name_ford pinto (sw)'),
#  (0.0, 'name_ford pinto'),
#  (0.0, 'name_ford mustang ii 2+2'),
#  (0.0, 'name_ford mustang ii'),
#  (0.0, 'name_ford mustang gl'),
#  (0.0, 'name_ford mustang cobra'),
#  (0.0, 'name_ford mustang'),
#  (0.0, 'name_ford maverick'),
#  (0.0, 'name_ford ltd landau'),
#  (0.0, 'name_ford ltd'),
#  (0.0, 'name_ford granada l'),
#  (0.0, 'name_ford granada gl'),
#  (0.0, 'name_ford granada ghia'),
#  (0.0, 'name_ford granada'),
#  (0.0, 'name_ford gran torino (sw)'),
#  (0.0, 'name_ford gran torino'),
#  (0.0, 'name_ford galaxie 500'),
#  (0.0, 'name_ford futura'),
#  (0.0, 'name_ford fiesta'),
#  (0.0, 'name_ford fairmont futura'),
#  (0.0, 'name_ford fairmont 4'),
#  (0.0, 'name_ford fairmont (man)'),
#  (0.0, 'name_ford fairmont (auto)'),
#  (0.0, 'name_ford fairmont'),
#  (0.0, 'name_ford f250'),
#  (0.0, 'name_ford f108'),
#  (0.0, 'name_ford escort 4w'),
#  (0.0, 'name_ford escort 2h'),
#  (0.0, 'name_ford country squire (sw)'),
#  (0.0, 'name_ford country'),
#  (0.0, 'name_fiat x1.9'),
#  (0.0, 'name_fiat strada custom'),
#  (0.0, 'name_fiat 131'),
#  (0.0, 'name_fiat 128'),
#  (0.0, 'name_fiat 124b'),
#  (0.0, 'name_fiat 124 tc'),
#  (0.0, 'name_fiat 124 sport coupe'),
#  (0.0, 'name_dodge st. regis'),
#  (0.0, 'name_dodge rampage'),
#  (0.0, 'name_dodge omni'),
#  (0.0, 'name_dodge monaco brougham'),
#  (0.0, 'name_dodge monaco (sw)'),
#  (0.0, 'name_dodge magnum xe'),
#  (0.0, 'name_dodge diplomat'),
#  (0.0, 'name_dodge dart custom'),
#  (0.0, 'name_dodge d200'),
#  (0.0, 'name_dodge d100'),
#  (0.0, 'name_dodge coronet custom (sw)'),
#  (0.0, 'name_dodge coronet custom'),
#  (0.0, 'name_dodge coronet brougham'),
#  (0.0, 'name_dodge colt m/m'),
#  (0.0, 'name_dodge colt hatchback custom'),
#  (0.0, 'name_dodge colt hardtop'),
#  (0.0, 'name_dodge colt (sw)'),
#  (0.0, 'name_dodge colt'),
#  (0.0, 'name_dodge charger 2.2'),
#  (0.0, 'name_dodge challenger se'),
#  (0.0, 'name_dodge aspen se'),
#  (0.0, 'name_dodge aspen 6'),
#  (0.0, 'name_dodge aspen'),
#  (0.0, 'name_dodge aries wagon (sw)'),
#  (0.0, 'name_dodge aries se'),
#  (0.0, 'name_datsun pl510'),
#  (0.0, 'name_datsun f-10 hatchback'),
#  (0.0, 'name_datsun b210 gx'),
#  (0.0, 'name_datsun b210'),
#  (0.0, 'name_datsun b-210'),
#  (0.0, 'name_datsun 810 maxima'),
#  (0.0, 'name_datsun 810'),
#  (0.0, 'name_datsun 710'),
#  (0.0, 'name_datsun 610'),
#  (0.0, 'name_datsun 510 hatchback'),
#  (0.0, 'name_datsun 510 (sw)'),
#  (0.0, 'name_datsun 510'),
#  (0.0, 'name_datsun 310 gx'),
#  (0.0, 'name_datsun 310'),
#  (0.0, 'name_datsun 280-zx'),
#  (0.0, 'name_datsun 210 mpg'),
#  (0.0, 'name_datsun 210'),
#  (0.0, 'name_datsun 200sx'),
#  (0.0, 'name_datsun 200-sx'),
#  (0.0, 'name_datsun 1200'),
#  (0.0, 'name_chrysler newport royal'),
#  (0.0, 'name_chrysler new yorker brougham'),
#  (0.0, 'name_chrysler lebaron town @ country (sw)'),
#  (0.0, 'name_chrysler lebaron salon'),
#  (0.0, 'name_chrysler lebaron medallion'),
#  (0.0, 'name_chrysler cordoba'),
#  (0.0, 'name_chevy s-10'),
#  (0.0, 'name_chevy c20'),
#  (0.0, 'name_chevy c10'),
#  (0.0, 'name_chevrolet woody'),
#  (0.0, 'name_chevrolet vega 2300'),
#  (0.0, 'name_chevrolet vega (sw)'),
#  (0.0, 'name_chevrolet vega'),
#  (0.0, 'name_chevrolet nova custom'),
#  (0.0, 'name_chevrolet nova'),
#  (0.0, 'name_chevrolet monza 2+2'),
#  (0.0, 'name_chevrolet monte carlo s'),
#  (0.0, 'name_chevrolet monte carlo landau'),
#  (0.0, 'name_chevrolet monte carlo'),
#  (0.0, 'name_chevrolet malibu classic (sw)'),
#  (0.0, 'name_chevrolet malibu'),
#  (0.0, 'name_chevrolet impala'),
#  (0.0, 'name_chevrolet concours'),
#  (0.0, 'name_chevrolet citation'),
#  (0.0, 'name_chevrolet chevette'),
#  (0.0, 'name_chevrolet chevelle malibu classic'),
#  (0.0, 'name_chevrolet chevelle malibu'),
#  (0.0, 'name_chevrolet chevelle concours (sw)'),
#  (0.0, 'name_chevrolet cavalier wagon'),
#  (0.0, 'name_chevrolet cavalier 2-door'),
#  (0.0, 'name_chevrolet cavalier'),
#  (0.0, 'name_chevrolet caprice classic'),
#  (0.0, 'name_chevrolet camaro'),
#  (0.0, 'name_chevrolet bel air'),
#  (0.0, 'name_chevroelt chevelle malibu'),
#  (0.0, 'name_capri ii'),
#  (0.0, 'name_cadillac seville'),
#  (0.0, 'name_cadillac eldorado'),
#  (0.0, 'name_buick skylark limited'),
#  (0.0, 'name_buick skylark 320'),
#  (0.0, 'name_buick skylark'),
#  (0.0, 'name_buick skyhawk'),
#  (0.0, 'name_buick regal sport coupe (turbo)'),
#  (0.0, 'name_buick opel isuzu deluxe'),
#  (0.0, 'name_buick lesabre custom'),
#  (0.0, 'name_buick estate wagon (sw)'),
#  (0.0, 'name_buick electra 225 custom'),
#  (0.0, 'name_buick century special'),
#  (0.0, 'name_buick century luxus (sw)'),
#  (0.0, 'name_buick century limited'),
#  (0.0, 'name_buick century 350'),
#  (0.0, 'name_buick century'),
#  (0.0, 'name_bmw 320i'),
#  (0.0, 'name_bmw 2002'),
#  (0.0, 'name_audi fox'),
#  (0.0, 'name_audi 5000s (diesel)'),
#  (0.0, 'name_audi 5000'),
#  (0.0, 'name_audi 4000'),
#  (0.0, 'name_audi 100ls'),
#  (0.0, 'name_audi 100 ls'),
#  (0.0, 'name_amc spirit dl'),
#  (0.0, 'name_amc rebel sst'),
#  (0.0, 'name_amc pacer d/l'),
#  (0.0, 'name_amc pacer'),
#  (0.0, 'name_amc matador (sw)'),
#  (0.0, 'name_amc matador'),
#  (0.0, 'name_amc hornet sportabout (sw)'),
#  (0.0, 'name_amc hornet'),
#  (0.0, 'name_amc gremlin'),
#  (0.0, 'name_amc concord dl 6'),
#  (0.0, 'name_amc concord d/l'),
#  (0.0, 'name_amc concord'),
#  (0.0, 'name_amc ambassador sst'),
#  (0.0, 'name_amc ambassador dpl'),
#  (0.0, 'name_amc ambassador brougham'),
#  (0.0, 'make_volkswagen'),
#  (0.0, 'make_triumph'),
#  (0.0, 'make_toyota'),
#  (0.0, 'make_subaru'),
#  (0.0, 'make_saab'),
#  (0.0, 'make_renault'),
#  (0.0, 'make_pontiac'),
#  (0.0, 'make_plymouth'),
#  (0.0, 'make_peugeot'),
#  (0.0, 'make_opel'),
#  (0.0, 'make_oldsmobile'),
#  (0.0, 'make_nissan'),
#  (0.0, 'make_mercedes-benz'),
#  (0.0, 'make_mazda'),
#  (0.0, 'make_honda'),
#  (0.0, 'make_hi'),
#  (0.0, 'make_ford'),
#  (0.0, 'make_fiat'),
#  (0.0, 'make_dodge'),
#  (0.0, 'make_datsun'),
#  (0.0, 'make_chrysler'),
#  (0.0, 'make_chevrolet'),
#  (0.0, 'make_capri'),
#  (0.0, 'make_cadillac'),
#  (0.0, 'make_buick'),
#  (0.0, 'make_bmw'),
#  (0.0, 'make_audi'),
#  (0.0, 'make_amc'),
#  (0.0, 'full_zephyr 6'),
#  (0.0, 'full_zephyr'),
#  (0.0, 'full_x1.9'),
#  (0.0, 'full_woody'),
#  (0.0, 'full_volare premier v8'),
#  (0.0, 'full_volare custom'),
#  (0.0, 'full_volare'),
#  (0.0, 'full_vista cruiser'),
#  (0.0, 'full_ventura sj'),
#  (0.0, 'full_vega 2300'),
#  (0.0, 'full_vega (sw)'),
#  (0.0, 'full_vega'),
#  (0.0, 'full_valiant custom'),
#  (0.0, 'full_valiant'),
#  (0.0, 'full_type 3'),
#  (0.0, 'full_tr7 coupe'),
#  (0.0, 'full_torino 500'),
#  (0.0, 'full_torino'),
#  (0.0, 'full_thunderbird'),
#  (0.0, 'full_tercel'),
#  (0.0, 'full_super beetle'),
#  (0.0, 'full_sunbird coupe'),
#  (0.0, 'full_strada custom'),
#  (0.0, 'full_starlet'),
#  (0.0, 'full_starfire sx'),
#  (0.0, 'full_stanza xe'),
#  (0.0, 'full_st. regis'),
#  (0.0, 'full_spirit dl'),
#  (0.0, 'full_skylark limited'),
#  (0.0, 'full_skylark 320'),
#  (0.0, 'full_skylark'),
#  (0.0, 'full_skyhawk'),
#  (0.0, 'full_seville'),
#  (0.0, 'full_scirocco'),
#  (0.0, 'full_satellite sebring'),
#  (0.0, 'full_satellite custom (sw)'),
#  (0.0, 'full_satellite custom'),
#  (0.0, 'full_satellite'),
#  (0.0, 'full_sapporo'),
#  (0.0, 'full_safari (sw)'),
#  (0.0, 'full_s-10'),
#  (0.0, 'full_rx3'),
#  (0.0, 'full_rx2 coupe'),
#  (0.0, 'full_rx-7 gs'),
#  (0.0, 'full_rx-4'),
#  (0.0, 'full_reliant'),
#  (0.0, 'full_regal sport coupe (turbo)'),
#  (0.0, 'full_rebel sst'),
#  (0.0, 'full_ranger'),
#  (0.0, 'full_rampage'),
#  (0.0, 'full_rabbit l'),
#  (0.0, 'full_rabbit custom diesel'),
#  (0.0, 'full_rabbit custom'),
#  (0.0, 'full_rabbit c (diesel)'),
#  (0.0, 'full_rabbit'),
#  (0.0, 'full_prelude'),
#  (0.0, 'full_pl510'),
#  (0.0, 'full_pinto runabout'),
#  (0.0, 'full_pinto (sw)'),
#  (0.0, 'full_pinto'),
#  (0.0, 'full_pickup'),
#  (0.0, 'full_phoenix lj'),
#  (0.0, 'full_phoenix'),
#  (0.0, 'full_pacer d/l'),
#  (0.0, 'full_pacer'),
#  (0.0, 'full_opel isuzu deluxe'),
#  (0.0, 'full_omni'),
#  (0.0, 'full_omega brougham'),
#  (0.0, 'full_omega'),
#  (0.0, 'full_nova custom'),
#  (0.0, 'full_nova'),
#  (0.0, 'full_newport royal'),
#  (0.0, 'full_new yorker brougham'),
#  (0.0, 'full_mustang ii 2+2'),
#  (0.0, 'full_mustang ii'),
#  (0.0, 'full_mustang gl'),
#  (0.0, 'full_mustang cobra'),
#  (0.0, 'full_mustang'),
#  (0.0, 'full_monza 2+2'),
#  (0.0, 'full_monte carlo s'),
#  (0.0, 'full_monte carlo landau'),
#  (0.0, 'full_monte carlo'),
#  (0.0, 'full_monarch ghia'),
#  (0.0, 'full_monarch'),
#  (0.0, 'full_monaco brougham'),
#  (0.0, 'full_monaco (sw)'),
#  (0.0, 'full_model 111'),
#  (0.0, 'full_maverick'),
#  (0.0, 'full_matador (sw)'),
#  (0.0, 'full_matador'),
#  (0.0, 'full_marquis brougham'),
#  (0.0, 'full_marquis'),
#  (0.0, 'full_mark ii'),
#  (0.0, 'full_manta'),
#  (0.0, 'full_malibu classic (sw)'),
#  (0.0, 'full_malibu'),
#  (0.0, 'full_magnum xe'),
#  (0.0, 'full_lynx l'),
#  (0.0, 'full_ltd landau'),
#  (0.0, 'full_ltd'),
#  (0.0, 'full_lesabre custom'),
#  (0.0, 'full_lemans v6'),
#  (0.0, 'full_lecar deluxe'),
#  (0.0, 'full_lebaron town @ country (sw)'),
#  (0.0, 'full_lebaron salon'),
#  (0.0, 'full_lebaron medallion'),
#  (0.0, 'full_jetta'),
#  (0.0, 'full_j2000 se hatchback'),
#  (0.0, 'full_impala'),
#  (0.0, 'full_ii'),
#  (0.0, 'full_hornet sportabout (sw)'),
#  (0.0, 'full_hornet'),
#  (0.0, 'full_horizon tc3'),
#  (0.0, 'full_horizon miser'),
#  (0.0, 'full_horizon 4'),
#  (0.0, 'full_horizon'),
#  (0.0, 'full_gremlin'),
#  (0.0, 'full_grand prix lj'),
#  (0.0, 'full_grand prix'),
#  (0.0, 'full_grand marquis'),
#  (0.0, 'full_grand fury'),
#  (0.0, 'full_granada l'),
#  (0.0, 'full_granada gl'),
#  (0.0, 'full_granada ghia'),
#  (0.0, 'full_granada'),
#  (0.0, 'full_gran torino (sw)'),
#  (0.0, 'full_gran torino'),
#  (0.0, 'full_glc deluxe'),
#  (0.0, 'full_glc custom l'),
#  (0.0, 'full_glc custom'),
#  (0.0, 'full_glc 4'),
#  (0.0, 'full_glc'),
#  (0.0, 'full_galaxie 500'),
#  (0.0, 'full_futura'),
#  (0.0, 'full_fury iii'),
#  (0.0, 'full_fury gran sedan'),
#  (0.0, 'full_fury'),
#  (0.0, 'full_fox'),
#  (0.0, 'full_firebird'),
#  (0.0, 'full_fiesta'),
#  (0.0, 'full_fairmont futura'),
#  (0.0, 'full_fairmont 4'),
#  (0.0, 'full_fairmont (man)'),
#  (0.0, 'full_fairmont (auto)'),
#  (0.0, 'full_fairmont'),
#  (0.0, 'full_f250'),
#  (0.0, 'full_f108'),
#  (0.0, 'full_f-10 hatchback'),
#  (0.0, 'full_estate wagon (sw)'),
#  (0.0, 'full_escort 4w'),
#  (0.0, 'full_escort 2h'),
#  (0.0, 'full_electra 225 custom'),
#  (0.0, 'full_eldorado'),
#  (0.0, 'full_duster'),
#  (0.0, 'full_dl'),
#  (0.0, 'full_diplomat'),
#  (0.0, 'full_diesel'),
#  (0.0, 'full_delta 88 royale'),
#  (0.0, 'full_dasher (diesel)'),
#  (0.0, 'full_dasher'),
#  (0.0, 'full_dart custom'),
#  (0.0, 'full_d200'),
#  (0.0, 'full_d100'),
#  (0.0, 'full_cutlass supreme'),
#  (0.0, 'full_cutlass salon brougham'),
#  (0.0, 'full_cutlass ls'),
#  (0.0, 'full_cutlass ciera (diesel)'),
#  (0.0, 'full_custom suburb'),
#  (0.0, 'full_cricket'),
#  (0.0, 'full_cressida'),
#  (0.0, 'full_country squire (sw)'),
#  (0.0, 'full_country'),
#  (0.0, 'full_cougar brougham'),
#  (0.0, 'full_coronet custom (sw)'),
#  (0.0, 'full_coronet custom'),
#  (0.0, 'full_coronet brougham'),
#  (0.0, 'full_corona mark ii (sw)'),
#  (0.0, 'full_corona mark ii'),
#  (0.0, 'full_corona liftback'),
#  (0.0, 'full_corona hardtop'),
#  (0.0, 'full_corona'),
#  (0.0, 'full_corolla tercel'),
#  (0.0, 'full_corolla liftback'),
#  (0.0, 'full_corolla 1600 (sw)'),
#  (0.0, 'full_corolla 1200'),
#  (0.0, 'full_corolla'),
#  (0.0, 'full_cordoba'),
#  (0.0, 'full_concours'),
#  (0.0, 'full_concord dl 6'),
#  (0.0, 'full_concord d/l'),
#  (0.0, 'full_concord'),
#  (0.0, 'full_colt m/m'),
#  (0.0, 'full_colt hatchback custom'),
#  (0.0, 'full_colt hardtop'),
#  (0.0, 'full_colt (sw)'),
#  (0.0, 'full_colt'),
#  (0.0, 'full_civic cvcc'),
#  (0.0, 'full_civic 1500 gl'),
#  (0.0, 'full_civic 1300'),
#  (0.0, 'full_civic (auto)'),
#  (0.0, 'full_civic'),
#  (0.0, 'full_citation'),
#  (0.0, 'full_chevette'),
#  (0.0, 'full_chevelle malibu classic'),
#  (0.0, 'full_chevelle malibu'),
#  (0.0, 'full_chevelle concours (sw)'),
#  (0.0, 'full_charger 2.2'),
#  (0.0, 'full_champ'),
#  (0.0, 'full_challenger se'),
#  (0.0, 'full_century special'),
#  (0.0, 'full_century luxus (sw)'),
#  (0.0, 'full_century limited'),
#  (0.0, 'full_century 350'),
#  (0.0, 'full_century'),
#  (0.0, 'full_celica gt liftback'),
#  (0.0, 'full_celica gt'),
#  (0.0, 'full_cavalier wagon'),
#  (0.0, 'full_cavalier 2-door'),
#  (0.0, 'full_cavalier'),
#  (0.0, 'full_catalina brougham'),
#  (0.0, 'full_catalina'),
#  (0.0, 'full_carina'),
#  (0.0, 'full_caprice classic'),
#  (0.0, 'full_capri v6'),
#  (0.0, 'full_capri 2000'),
#  (0.0, 'full_camaro'),
#  (0.0, 'full_c20'),
#  (0.0, 'full_c10'),
#  (0.0, 'full_benz 300d'),
#  (0.0, 'full_bel air'),
#  (0.0, 'full_b210 gx'),
#  (0.0, 'full_b210'),
#  (0.0, 'full_b-210'),
#  (0.0, 'full_astro'),
#  (0.0, 'full_aspen se'),
#  (0.0, 'full_aspen 6'),
#  (0.0, 'full_aspen'),
#  (0.0, 'full_arrow gs'),
#  (0.0, 'full_aries wagon (sw)'),
#  (0.0, 'full_aries se'),
#  (0.0, 'full_ambassador sst'),
#  (0.0, 'full_ambassador dpl'),
#  (0.0, 'full_ambassador brougham'),
#  (0.0, 'full_accord lx'),
#  (0.0, 'full_accord cvcc'),
#  (0.0, 'full_accord'),
#  (0.0, 'full_99le'),
#  (0.0, 'full_99gle'),
#  (0.0, 'full_99e'),
#  (0.0, 'full_810 maxima'),
#  (0.0, 'full_810'),
#  (0.0, 'full_710'),
#  (0.0, 'full_626'),
#  (0.0, 'full_610'),
#  (0.0, 'full_604sl'),
#  (0.0, 'full_510 hatchback'),
#  (0.0, 'full_510 (sw)'),
#  (0.0, 'full_510'),
#  (0.0, 'full_505s turbo diesel'),
#  (0.0, 'full_504 (sw)'),
#  (0.0, 'full_504'),
#  (0.0, 'full_5000s (diesel)'),
#  (0.0, 'full_5000'),
#  (0.0, 'full_5 gtl'),
#  (0.0, 'full_411 (sw)'),
#  (0.0, 'full_4000'),
#  (0.0, 'full_320i'),
#  (0.0, 'full_310 gx'),
#  (0.0, 'full_310'),
#  (0.0, 'full_304'),
#  (0.0, 'full_280s'),
#  (0.0, 'full_280-zx'),
#  (0.0, 'full_264gl'),
#  (0.0, 'full_245'),
#  (0.0, 'full_244dl'),
#  (0.0, 'full_240d'),
#  (0.0, 'full_210 mpg'),
#  (0.0, 'full_210'),
#  (0.0, 'full_200sx'),
#  (0.0, 'full_2002'),
#  (0.0, 'full_200-sx'),
#  (0.0, 'full_1900'),
#  (0.0, 'full_18i'),
#  (0.0, 'full_145e (sw)'),
#  (0.0, 'full_144ea'),
#  (0.0, 'full_131'),
#  (0.0, 'full_12tl'),
#  (0.0, 'full_128'),
#  (0.0, 'full_124b'),
#  (0.0, 'full_124 tc'),
#  (0.0, 'full_124 sport coupe'),
#  (0.0, 'full_1200d'),
#  (0.0, 'full_1200'),
#  (0.0, 'full_12 (sw)'),
#  (0.0, 'full_1131 deluxe sedan'),
#  (0.0, 'full_100ls'),
#  (0.0, 'full_100 ls'),
#  (0.0, "full_'cuda 340"),
#  (0.0, 'full_'),
#  (0.0, 'cyli_6'),
#  (0.0, 'cyli_5'),
#  (0.0, 'cyli_3'),
#  (0.0, 'basi_zephyr'),
#  (0.0, 'basi_x1.9'),
#  (0.0, 'basi_woody'),
#  (0.0, 'basi_volare'),
#  (0.0, 'basi_vista'),
#  (0.0, 'basi_ventura'),
#  (0.0, 'basi_vega'),
#  (0.0, 'basi_valiant'),
#  (0.0, 'basi_tr7'),
#  (0.0, 'basi_torino'),
#  (0.0, 'basi_thunderbird'),
#  (0.0, 'basi_tercel'),
#  (0.0, 'basi_super'),
#  (0.0, 'basi_sunbird'),
#  (0.0, 'basi_strada'),
#  (0.0, 'basi_starlet'),
#  (0.0, 'basi_starfire'),
#  (0.0, 'basi_stanza'),
#  (0.0, 'basi_st.'),
#  (0.0, 'basi_spirit'),
#  (0.0, 'basi_skylark'),
#  (0.0, 'basi_skyhawk'),
#  (0.0, 'basi_seville'),
#  (0.0, 'basi_scirocco'),
#  (0.0, 'basi_satellite'),
#  (0.0, 'basi_sapporo'),
#  (0.0, 'basi_safari'),
#  (0.0, 'basi_s-10'),
#  (0.0, 'basi_rx3'),
#  (0.0, 'basi_rx2'),
#  (0.0, 'basi_rx-7'),
#  (0.0, 'basi_rx-4'),
#  (0.0, 'basi_reliant'),
#  (0.0, 'basi_regal'),
#  (0.0, 'basi_rebel'),
#  (0.0, 'basi_ranger'),
#  (0.0, 'basi_rampage'),
#  (0.0, 'basi_rabbit'),
#  (0.0, 'basi_prelude'),
#  (0.0, 'basi_pl510'),
#  (0.0, 'basi_pinto'),
#  (0.0, 'basi_pickup'),
#  (0.0, 'basi_phoenix'),
#  (0.0, 'basi_pacer'),
#  (0.0, 'basi_opel'),
#  (0.0, 'basi_omni'),
#  (0.0, 'basi_omega'),
#  (0.0, 'basi_nova'),
#  (0.0, 'basi_newport'),
#  (0.0, 'basi_new'),
#  (0.0, 'basi_mustang'),
#  (0.0, 'basi_monza'),
#  (0.0, 'basi_monte'),
#  (0.0, 'basi_monarch'),
#  (0.0, 'basi_monaco'),
#  (0.0, 'basi_model'),
#  (0.0, 'basi_matador'),
#  (0.0, 'basi_marquis'),
#  (0.0, 'basi_mark'),
#  (0.0, 'basi_manta'),
#  (0.0, 'basi_malibu'),
#  (0.0, 'basi_magnum'),
#  (0.0, 'basi_lynx'),
#  (0.0, 'basi_ltd'),
#  (0.0, 'basi_lesabre'),
#  (0.0, 'basi_lemans'),
#  (0.0, 'basi_lecar'),
#  (0.0, 'basi_lebaron'),
#  (0.0, 'basi_jetta'),
#  (0.0, 'basi_j2000'),
#  (0.0, 'basi_impala'),
#  (0.0, 'basi_ii'),
#  (0.0, 'basi_hornet'),
#  (0.0, 'basi_horizon'),
#  (0.0, 'basi_gremlin'),
#  (0.0, 'basi_grand'),
#  (0.0, 'basi_granada'),
#  (0.0, 'basi_gran'),
#  (0.0, 'basi_glc'),
#  (0.0, 'basi_galaxie'),
#  (0.0, 'basi_futura'),
#  (0.0, 'basi_fury'),
#  (0.0, 'basi_fox'),
#  (0.0, 'basi_firebird'),
#  (0.0, 'basi_fiesta'),
#  (0.0, 'basi_fairmont'),
#  (0.0, 'basi_f250'),
#  (0.0, 'basi_f108'),
#  (0.0, 'basi_f-10'),
#  (0.0, 'basi_estate'),
#  (0.0, 'basi_escort'),
#  (0.0, 'basi_electra'),
#  (0.0, 'basi_eldorado'),
#  (0.0, 'basi_duster'),
#  (0.0, 'basi_dl'),
#  (0.0, 'basi_diplomat'),
#  (0.0, 'basi_diesel'),
#  (0.0, 'basi_delta'),
#  (0.0, 'basi_dasher'),
#  (0.0, 'basi_dart'),
#  (0.0, 'basi_d200'),
#  (0.0, 'basi_d100'),
#  (0.0, 'basi_cutlass'),
#  (0.0, 'basi_custom'),
#  (0.0, 'basi_cricket'),
#  (0.0, 'basi_cressida'),
#  (0.0, 'basi_country'),
#  (0.0, 'basi_cougar'),
#  (0.0, 'basi_coronet'),
#  (0.0, 'basi_corona'),
#  (0.0, 'basi_corolla'),
#  (0.0, 'basi_cordoba'),
#  (0.0, 'basi_concours'),
#  (0.0, 'basi_concord'),
#  (0.0, 'basi_colt'),
#  (0.0, 'basi_civic'),
#  (0.0, 'basi_citation'),
#  (0.0, 'basi_chevette'),
#  (0.0, 'basi_chevelle'),
#  (0.0, 'basi_charger'),
#  (0.0, 'basi_champ'),
#  (0.0, 'basi_challenger'),
#  (0.0, 'basi_century'),
#  (0.0, 'basi_cavalier'),
#  (0.0, 'basi_catalina'),
#  (0.0, 'basi_carina'),
#  (0.0, 'basi_caprice'),
#  (0.0, 'basi_capri'),
#  (0.0, 'basi_camaro'),
#  (0.0, 'basi_c20'),
#  (0.0, 'basi_c10'),
#  (0.0, 'basi_benz'),
#  (0.0, 'basi_bel'),
#  (0.0, 'basi_b210'),
#  (0.0, 'basi_b-210'),
#  (0.0, 'basi_astro'),
#  (0.0, 'basi_aspen'),
#  (0.0, 'basi_arrow'),
#  (0.0, 'basi_aries'),
#  (0.0, 'basi_ambassador'),
#  (0.0, 'basi_accord'),
#  (0.0, 'basi_99le'),
#  (0.0, 'basi_99gle'),
#  (0.0, 'basi_99e'),
#  (0.0, 'basi_810'),
#  (0.0, 'basi_710'),
#  (0.0, 'basi_626'),
#  (0.0, 'basi_610'),
#  (0.0, 'basi_604sl'),
#  (0.0, 'basi_510'),
#  (0.0, 'basi_505s'),
#  (0.0, 'basi_504'),
#  (0.0, 'basi_5000s'),
#  (0.0, 'basi_5000'),
#  (0.0, 'basi_5'),
#  (0.0, 'basi_411'),
#  (0.0, 'basi_4000'),
#  (0.0, 'basi_310'),
#  (0.0, 'basi_304'),
#  (0.0, 'basi_280s'),
#  (0.0, 'basi_280-zx'),
#  (0.0, 'basi_264gl'),
#  (0.0, 'basi_245'),
#  (0.0, 'basi_244dl'),
#  (0.0, 'basi_240d'),
#  (0.0, 'basi_210'),
#  (0.0, 'basi_200sx'),
#  (0.0, 'basi_2002'),
#  (0.0, 'basi_200-sx'),
#  (0.0, 'basi_1900'),
#  (0.0, 'basi_18i'),
#  (0.0, 'basi_145e'),
#  (0.0, 'basi_144ea'),
#  (0.0, 'basi_131'),
#  (0.0, 'basi_12tl'),
#  (0.0, 'basi_128'),
#  (0.0, 'basi_124b'),
#  (0.0, 'basi_124'),
#  (0.0, 'basi_1200d'),
#  (0.0, 'basi_1200'),
#  (0.0, 'basi_12'),
#  (0.0, 'basi_1131'),
#  (0.0, 'basi_100ls'),
#  (0.0, 'basi_100'),
#  (0.0, "basi_'cuda"),
#  (0.0, 'basi_')]
